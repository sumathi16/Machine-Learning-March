# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.random.random(50)
x
# Out:
# array([0.95520916, 0.47244071, 0.73701984, 0.28669678, 0.87218443,
#        0.64168972, 0.41798678, 0.53373174, 0.13766799, 0.64563747,
#        0.74221876, 0.62311717, 0.01405448, 0.70456564, 0.19107815,
#        0.27098853, 0.254459  , 0.19068676, 0.68153459, 0.95666416,
#        0.23003177, 0.29580733, 0.34849132, 0.08066184, 0.3955608 ,
#        0.03680184, 0.54694402, 0.09288669, 0.66474935, 0.90870902,
#        0.77378404, 0.33243356, 0.6224533 , 0.64664093, 0.21279801,
#        0.72326099, 0.52528468, 0.97344335, 0.11406783, 0.79216392,
#        0.37043209, 0.70858365, 0.91362508, 0.82721139, 0.9736028 ,
#        0.31448409, 0.7608424 , 0.90785561, 0.42499204, 0.59427477])

# %%
y = np.log(x) +3*x
# x2 --> np.log(x)
# x1 --> x
# y = x2 + 3 x1
# y = 1*x2 + 3*x1 + 0

# %%
plt.plot(x,y,'o')

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression() 
LR.fit(x.reshape(-1,1),y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
LR.intercept_
# Out:
# -2.3551742889906526

# %%
LR.coef_
# Out:
# array([5.77482514])

# %%
plt.plot(x,y,'ro')
plt.plot(x,LR.predict(x.reshape(-1,1)),'bo')

# %%
df = pd.DataFrame()
df['x1'] = x
df['x2'] = np.log(x)
df
# Out:
#           x1        x2
# 0   0.955209 -0.045825
# 1   0.472441 -0.749843
# 2   0.737020 -0.305140
# 3   0.286697 -1.249330
# 4   0.872184 -0.136754
# 5   0.641690 -0.443650
# 6   0.417987 -0.872305
# 7   0.533732 -0.627862
# 8   0.137668 -1.982910
# 9   0.645637 -0.437517
# 10  0.742219 -0.298111
# 11  0.623117 -0.473021
# 12  0.014054 -4.264814
# 13  0.704566 -0.350174
# 14  0.191078 -1.655073
# 15  0.270989 -1.305679
# 16  0.254459 -1.368616
# 17  0.190687 -1.657123
# 18  0.681535 -0.383408
# 19  0.956664 -0.044303
# 20  0.230032 -1.469538
# 21  0.295807 -1.218047
# 22  0.348491 -1.054142
# 23  0.080662 -2.517490
# 24  0.395561 -0.927451
# 25  0.036802 -3.302207
# 26  0.546944 -0.603409
# 27  0.092887 -2.376375
# 28  0.664749 -0.408345
# 29  0.908709 -0.095730
# 30  0.773784 -0.256462
# 31  0.332434 -1.101315
# 32  0.622453 -0.474087
# 33  0.646641 -0.435964
# 34  0.212798 -1.547412
# 35  0.723261 -0.323985
# 36  0.525285 -0.643815
# 37  0.973443 -0.026916
# 38  0.114068 -2.170962
# 39  0.792164 -0.232987
# 40  0.370432 -0.993085
# 41  0.708584 -0.344487
# 42  0.913625 -0.090335
# 43  0.827211 -0.189695
# 44  0.973603 -0.026752
# 45  0.314484 -1.156822
# 46  0.760842 -0.273329
# 47  0.907856 -0.096670
# 48  0.424992 -0.855685
# 49  0.594275 -0.520413

# %%
LR1 = LinearRegression()
LR1.fit(df,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# y = 1*x2 + 3*x1 + 0
print(LR1.intercept_,LR1.coef_)
# Out:
# 7.771561172376096e-16 [3. 1.]

# %%
plt.scatter(np.log(x),y)

# %%
plt.scatter(x**3,y)

# %%
# Polynomial
from sklearn.preprocessing import PolynomialFeatures
PF = PolynomialFeatures(degree=2)
PF.fit(df[['x1']])
PF.transform(df[['x1']])
# Out:
# array([[1.00000000e+00, 9.55209161e-01, 9.12424541e-01],
#        [1.00000000e+00, 4.72440709e-01, 2.23200223e-01],
#        [1.00000000e+00, 7.37019840e-01, 5.43198245e-01],
#        [1.00000000e+00, 2.86696776e-01, 8.21950413e-02],
#        [1.00000000e+00, 8.72184434e-01, 7.60705687e-01],
#        [1.00000000e+00, 6.41689721e-01, 4.11765698e-01],
#        [1.00000000e+00, 4.17986776e-01, 1.74712945e-01],
#        [1.00000000e+00, 5.33731737e-01, 2.84869567e-01],
#        [1.00000000e+00, 1.37667989e-01, 1.89524752e-02],
#        [1.00000000e+00, 6.45637471e-01, 4.16847744e-01],
#        [1.00000000e+00, 7.42218758e-01, 5.50888684e-01],
#        [1.00000000e+00, 6.23117175e-01, 3.88275014e-01],
#        [1.00000000e+00, 1.40544792e-02, 1.97528385e-04],
#        [1.00000000e+00, 7.04565637e-01, 4.96412737e-01],
#        [1.00000000e+00, 1.91078146e-01, 3.65108580e-02],
#        [1.00000000e+00, 2.70988533e-01, 7.34347849e-02],
#        [1.00000000e+00, 2.54458996e-01, 6.47493808e-02],
#        [1.00000000e+00, 1.90686757e-01, 3.63614392e-02],
#        [1.00000000e+00, 6.81534595e-01, 4.64489404e-01],
#        [1.00000000e+00, 9.56664157e-01, 9.15206309e-01],
#        [1.00000000e+00, 2.30031765e-01, 5.29146131e-02],
#        [1.00000000e+00, 2.95807328e-01, 8.75019754e-02],
#        [1.00000000e+00, 3.48491318e-01, 1.21446199e-01],
#        [1.00000000e+00, 8.06618423e-02, 6.50633281e-03],
#        [1.00000000e+00, 3.95560798e-01, 1.56468345e-01],
#        [1.00000000e+00, 3.68018399e-02, 1.35437542e-03],
#        [1.00000000e+00, 5.46944024e-01, 2.99147765e-01],
#        [1.00000000e+00, 9.28866891e-02, 8.62793702e-03],
#        [1.00000000e+00, 6.64749353e-01, 4.41891703e-01],
#        [1.00000000e+00, 9.08709019e-01, 8.25752081e-01],
#        [1.00000000e+00, 7.73784037e-01, 5.98741736e-01],
#        [1.00000000e+00, 3.32433556e-01, 1.10512069e-01],
#        [1.00000000e+00, 6.22453305e-01, 3.87448116e-01],
#        [1.00000000e+00, 6.46640927e-01, 4.18144489e-01],
#        [1.00000000e+00, 2.12798011e-01, 4.52829934e-02],
#        [1.00000000e+00, 7.23260991e-01, 5.23106461e-01],
#        [1.00000000e+00, 5.25284683e-01, 2.75923998e-01],
#        [1.00000000e+00, 9.73443353e-01, 9.47591961e-01],
#        [1.00000000e+00, 1.14067825e-01, 1.30114688e-02],
#        [1.00000000e+00, 7.92163923e-01, 6.27523680e-01],
#        [1.00000000e+00, 3.70432088e-01, 1.37219931e-01],
#        [1.00000000e+00, 7.08583654e-01, 5.02090795e-01],
#        [1.00000000e+00, 9.13625081e-01, 8.34710788e-01],
#        [1.00000000e+00, 8.27211390e-01, 6.84278683e-01],
#        [1.00000000e+00, 9.73602801e-01, 9.47902413e-01],
#        [1.00000000e+00, 3.14484085e-01, 9.89002399e-02],
#        [1.00000000e+00, 7.60842398e-01, 5.78881155e-01],
#        [1.00000000e+00, 9.07855606e-01, 8.24201802e-01],
#        [1.00000000e+00, 4.24992037e-01, 1.80618231e-01],
#        [1.00000000e+00, 5.94274766e-01, 3.53162498e-01]])

# %%
from sklearn.preprocessing import PolynomialFeatures
PF = PolynomialFeatures(degree=3)
PF.fit(df[['x1']])
poly_df = pd.DataFrame(PF.transform(df[['x1']]),columns=["x1","x2","x3","x4"])

# %%
poly_df
# Out:
#      x1        x2        x3        x4
# 0   1.0  0.955209  0.912425  0.871556
# 1   1.0  0.472441  0.223200  0.105449
# 2   1.0  0.737020  0.543198  0.400348
# 3   1.0  0.286697  0.082195  0.023565
# 4   1.0  0.872184  0.760706  0.663476
# 5   1.0  0.641690  0.411766  0.264226
# 6   1.0  0.417987  0.174713  0.073028
# 7   1.0  0.533732  0.284870  0.152044
# 8   1.0  0.137668  0.018952  0.002609
# 9   1.0  0.645637  0.416848  0.269133
# 10  1.0  0.742219  0.550889  0.408880
# 11  1.0  0.623117  0.388275  0.241941
# 12  1.0  0.014054  0.000198  0.000003
# 13  1.0  0.704566  0.496413  0.349755
# 14  1.0  0.191078  0.036511  0.006976
# 15  1.0  0.270989  0.073435  0.019900
# 16  1.0  0.254459  0.064749  0.016476
# 17  1.0  0.190687  0.036361  0.006934
# 18  1.0  0.681535  0.464489  0.316566
# 19  1.0  0.956664  0.915206  0.875545
# 20  1.0  0.230032  0.052915  0.012172
# 21  1.0  0.295807  0.087502  0.025884
# 22  1.0  0.348491  0.121446  0.042323
# 23  1.0  0.080662  0.006506  0.000525
# 24  1.0  0.395561  0.156468  0.061893
# 25  1.0  0.036802  0.001354  0.000050
# 26  1.0  0.546944  0.299148  0.163617
# 27  1.0  0.092887  0.008628  0.000801
# 28  1.0  0.664749  0.441892  0.293747
# 29  1.0  0.908709  0.825752  0.750368
# 30  1.0  0.773784  0.598742  0.463297
# 31  1.0  0.332434  0.110512  0.036738
# 32  1.0  0.622453  0.387448  0.241168
# 33  1.0  0.646641  0.418144  0.270389
# 34  1.0  0.212798  0.045283  0.009636
# 35  1.0  0.723261  0.523106  0.378342
# 36  1.0  0.525285  0.275924  0.144939
# 37  1.0  0.973443  0.947592  0.922427
# 38  1.0  0.114068  0.013011  0.001484
# 39  1.0  0.792164  0.627524  0.497102
# 40  1.0  0.370432  0.137220  0.050831
# 41  1.0  0.708584  0.502091  0.355773
# 42  1.0  0.913625  0.834711  0.762613
# 43  1.0  0.827211  0.684279  0.566043
# 44  1.0  0.973603  0.947902  0.922880
# 45  1.0  0.314484  0.098900  0.031103
# 46  1.0  0.760842  0.578881  0.440437
# 47  1.0  0.907856  0.824202  0.748256
# 48  1.0  0.424992  0.180618  0.076761
# 49  1.0  0.594275  0.353162  0.209876

# %%
poly_df['y'] = y

# %%
poly_df.corr()
# Out:
#     x1        x2        x3        x4         y
# x1 NaN       NaN       NaN       NaN       NaN
# x2 NaN  1.000000  0.970503  0.919457  0.972304
# x3 NaN  0.970503  1.000000  0.985737  0.898472
# x4 NaN  0.919457  0.985737  1.000000  0.828884
# y  NaN  0.972304  0.898472  0.828884  1.000000

# %% [markdown]
# Regularization
# - x1,x2 -->are in same range
# - b1,b2
# - b1 =1
# - b2 =100000
