# %%
classification
- Binary
- Multiclass
- Sentiment Analysis
- Anomly detection 
Regression
Recommender Systems
Reinforcement Learning
NLP
- Q&A
- Auto completion
- Chatbot
Computer Vision
- Object detection
- Object tracking
- image classfication
- image tagging
Data
- numerical data
- image data
- audio data
- video data
- text data
- from documents
- satellite imagery
- timeseries data(Temperatue Reading, Stock prices)
